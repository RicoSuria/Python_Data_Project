# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# # Counts of Job Titles
# ![image.png](attachment:image.png)
# pivot_table ada values, index, column, dan aggfunc

# %%
df.pivot_table(values='salary_year_avg', index='job_country',columns='job_title_short', aggfunc='mean')
# Out:
# job_title_short  Business Analyst  Cloud Engineer   Data Analyst  \
# job_country
# Albania                       NaN             NaN   49950.000000
# Algeria                       NaN             NaN   44100.000000
# Argentina            71100.000000        197500.0   85436.375000
# Armenia                       NaN             NaN  100500.000000
# Australia            87666.666667        110000.0  102875.000000
# ...                           ...             ...            ...
# Uruguay                       NaN             NaN  100500.000000
# Uzbekistan                    NaN             NaN            NaN
# Vietnam              74400.000000             NaN   90842.454545
# Zambia                        NaN             NaN            NaN
# Zimbabwe                      NaN             NaN   63000.000000
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Albania                    NaN    69981.250000                        NaN
# Algeria           45000.000000             NaN                        NaN
# Argentina         94276.846154    99536.916667              131009.666667
# Armenia           48750.000000             NaN               87021.000000
# Australia        112479.983333   139755.857143              122304.142857
# ...                        ...             ...                        ...
# Uruguay                    NaN             NaN               50000.000000
# Uzbekistan                 NaN    30750.000000                        NaN
# Vietnam           98508.187500    89066.666667               71381.250000
# Zambia                     NaN    90670.000000                        NaN
# Zimbabwe                   NaN    69085.000000                        NaN
#
# job_title_short  Senior Data Analyst  Senior Data Engineer  \
# job_country
# Albania                          NaN                   NaN
# Algeria                          NaN                   NaN
# Argentina                        NaN              147500.0
# Armenia                          NaN                   NaN
# Australia                    50640.0              119894.0
# ...                              ...                   ...
# Uruguay                          NaN                   NaN
# Uzbekistan                       NaN                   NaN
# Vietnam                     100512.5              127125.0
# Zambia                           NaN                   NaN
# Zimbabwe                         NaN                   NaN
#
# job_title_short  Senior Data Scientist  Software Engineer
# job_country
# Albania                       157500.0                NaN
# Algeria                            NaN                NaN
# Argentina                          NaN      174500.000000
# Armenia                            NaN                NaN
# Australia                     157500.0      140655.833333
# ...                                ...                ...
# Uruguay                        57500.0                NaN
# Uzbekistan                         NaN                NaN
# Vietnam                        79200.0       53600.000000
# Zambia                             NaN                NaN
# Zimbabwe                           NaN                NaN
#
# [108 rows x 10 columns]

# %%
top_countries = df['job_country'].value_counts().head(6).index

df_job_country_salary = df.pivot_table(
    values='salary_year_avg',
    index='job_country',
    columns='job_title_short',
    aggfunc='median'
)

df_job_country_salary = df_job_country_salary.loc[top_countries]

job_titles = ['Data Analyst', 'Data Engineer', 'Data Scientist']

df_job_country_salary = df_job_country_salary[job_titles]

df_job_country_salary.plot(kind='bar')
# Out:
# <Axes: xlabel='job_country'>
